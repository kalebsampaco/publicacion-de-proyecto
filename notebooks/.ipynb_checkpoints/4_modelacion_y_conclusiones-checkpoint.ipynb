# %%
# %matplotlib inline
import pandas as pd

# %%
compras_df = pd.read_csv('data/compras_df_enriched.csv')

# %% [markdown]
# ## Probar un modelo supervisado

# %%
data = compras_df.copy()
for i, column in enumerate(list([str(d) for d in data.dtypes])):
    if column == "object":
        data[data.columns[i]] = data[data.columns[i]].fillna(data[data.columns[i]].mode())
        data[data.columns[i]] = data[data.columns[i]].astype("category").cat.codes
    else:
        data[data.columns[i]] = data[data.columns[i]].fillna(data[data.columns[i]]).median()

# %%
data.head()
# Out:
#     NUM BEN  BENEFICIARIO  RFC  FACTURA  CONTRATO  CONCEPTO  TIPO  \
# 0  203016.0           160  165     1342       111       752     1
# 1  203016.0           160  165     1343       116       817     1
# 2  203016.0           160  165     1344       113       731     1
# 3  203016.0           160  165     1345       112       729     1
# 4  203016.0           160  165     1346       398       831     1
#
#           # OP  FECHA   IMPORTE  SHEET   DIA   MES    ANIO    YEAR  \
# 0  298000055.0      8  10465.02      1  11.0  12.0  2020.0  2020.0
# 1  298000055.0      8  10465.02      1  11.0  12.0  2020.0  2020.0
# 2  298000055.0      8  10465.02      1  11.0  12.0  2020.0  2020.0
# 3  298000055.0      8  10465.02      1  11.0  12.0  2020.0  2020.0
# 4  298000055.0     16  10465.02      1  11.0  12.0  2020.0  2020.0
#
#    BENEFICIARIO_SALE  IMPORTE_GASTOS_PROMEDIO  HAS_LINKEDIN_SITE
# 0               21.0            474566.765787                1.0
# 1               21.0            474566.765787                1.0
# 2               21.0            474566.765787                1.0
# 3               21.0            474566.765787                1.0
# 4               21.0            474566.765787                1.0

# %%
from sklearn.ensemble  import RandomForestRegressor
from sklearn.model_selection import train_test_split

# %%
y = data.pop('IMPORTE')
X = data.copy()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
clf = RandomForestRegressor(n_estimators=1000, max_depth=4)

# %%
clf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=4, n_estimators=1000)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, clf.predict(X_test))
# Out:
# -24344.911340206185

# %% [markdown]
# ## Probar un modelo no supervisado o de clustering para texto

# %%
import gensim
from nltk.corpus import stopwords
import numpy as np
np.random.seed(2023)

# %%
def preprocess(text):
    result = []
    for token in text.split():
        if token not in stopwords.words('spanish') and len(text)>4:
            result.append(token)
    return result

# %%
process_business = [preprocess(x) for x in list(compras_df['BENEFICIARIO'].unique())]

# %%
dictionary = gensim.corpora.Dictionary(process_business)

# %%
dictionary.filter_extremes(no_below=1, no_above=0.5)

# %%
bow_corpus = [dictionary.doc2bow(doc) for doc in process_business]

# %%
lda_model = gensim.models.LdaMulticore(bow_corpus, num_topics=6, id2word=dictionary, passes=10, workers=2)

# %%
for idx, type_business in lda_model.print_topics(-1):
    print('Topic:{} Words:{}'.format(idx, type_business))
# Out:
# Topic:0 Words:0.028*"SA." + 0.028*"CV." + 0.024*"Y" + 0.014*"C.V." + 0.012*"SANCHEZ" + 0.012*"SAN" + 0.012*"NUEVO" + 0.012*"LEON," + 0.012*"CONSTRUCTORA" + 0.008*"MARCELO"
# Topic:1 Words:0.095*"C.V." + 0.069*"S.A." + 0.011*"JOSE" + 0.008*"CONSTRUCTORA" + 0.007*"ARTURO" + 0.007*"TORRES" + 0.007*"MONTERREY," + 0.007*"LA" + 0.007*"REGIOMONTANA," + 0.007*"VALDES"
# Topic:2 Words:0.062*"S.A." + 0.062*"C.V." + 0.017*"SEGUROS" + 0.014*"GAS" + 0.014*"GRUPO" + 0.012*"DEL" + 0.011*"MARIA" + 0.010*"MONTERREY," + 0.010*"MEXICO," + 0.010*"FINANCIERO"
# Topic:3 Words:0.046*"C.V." + 0.032*"Y" + 0.032*"S.A." + 0.021*"GONZALEZ" + 0.015*"GARCIA" + 0.012*"GARZA" + 0.009*"RODRIGUEZ" + 0.009*"MARIA" + 0.009*"GOMEZ" + 0.009*"MEXICO,"
# Topic:4 Words:0.057*"CV." + 0.056*"SA." + 0.049*"Y" + 0.016*"CONSTRUCCIONES" + 0.011*"C.V." + 0.009*"GARCIA" + 0.009*"INFRAESTRUCTURA" + 0.008*"S.A." + 0.006*"RAMIREZ" + 0.006*"CONSTRUCCIONES,"
# Topic:5 Words:0.059*"C.V." + 0.056*"S.A." + 0.036*"CV." + 0.033*"SA." + 0.012*"LA" + 0.012*"DESARROLLOS" + 0.009*"MARIA" + 0.009*"DEL" + 0.009*"CONSTRUCTORA" + 0.009*"SANCHEZ"

# %%
def get_max_topic(index):
    result = lda_model[bow_corpus[index]]
    return max(lda_model[result], key= lambda x: x[1])[0]

# %%
business_cluster = {x: get_max_topic(i) for i, x in enumerate(list(compras_df['BENEFICIARIO'].unique()))}

# %%
compras_df['CLUSTER_NAME'] = compras_df['BENEFICIARIO'].apply(lambda x: business_cluster[x])

# %%
compras_df['CLUSTER_NAME'].head(5)
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: CLUSTER_NAME, dtype: int64

# %%
compras_df['CLUSTER_NAME'].value_counts()
# Out:
# 4    1032
# 1     285
# 0     134
# 5      12
# 3       6
# Name: CLUSTER_NAME, dtype: int64

# %%
compras_df.groupby('CLUSTER_NAME')['IMPORTE'].mean().plot.bar()
# Out:
# <AxesSubplot: xlabel='CLUSTER_NAME'>

# %% [markdown]
# ## Probar un modelo no supervisado de anomalías en cuanto a importes

# %%
import numpy as np
from scipy.stats import norm

# %%
params = norm.fit(compras_df['IMPORTE'])

# %%
params
# Out:
# (651286.9703948264, 4775337.997790506)

# %%
compras_df['PROB_TOTAL'] = [norm(params[0], params[1]).cdf(x) for x in compras_df['IMPORTE']]

# %%
compras_df['PROB_TOTAL'].hist()
# Out:
# <AxesSubplot: >

# %%
compras_df[compras_df['PROB_TOTAL']>0.95]
# Out:
#      NUM BEN                                       BENEFICIARIO           RFC  \
# 283   116684                INDUSTRIAS SOLA BASIC, S.A. DE C.V.  ISB840628IB2
# 353   126224                          BANCO MULTIVA, SA. G.F.M.  BMI061005NY5
# 354   126224                          BANCO MULTIVA, SA. G.F.M.  BMI061005NY5
# 357   126671       BANCO BANCREA,S.A. ,FIDEICOMISO NUMERO BP417  BBA130722BR7
# 367   206894                MUNICIPIO DE LA CIUDAD DE MONTERREY  MCM610101PT2
# 368   206894                MUNICIPIO DE LA CIUDAD DE MONTERREY  MCM610101PT2
# 369   206894                MUNICIPIO DE LA CIUDAD DE MONTERREY  MCM610101PT2
# 370   206894                MUNICIPIO DE LA CIUDAD DE MONTERREY  MCM610101PT2
# 372   206894                MUNICIPIO DE LA CIUDAD DE MONTERREY  MCM610101PT2
# 354  2020-12-18  9.078245e+06           GASTOS VARIOS   18   12  2020  2020
# 357  2020-12-11  3.000000e+07           GASTOS VARIOS   11   12  2020  2020
# 367  2020-12-17  7.386437e+07           GASTOS VARIOS   17   12  2020  2020
# 368  2020-12-17  7.635249e+07           GASTOS VARIOS   17   12  2020  2020
# 369  2020-12-17  1.924614e+07           GASTOS VARIOS   17   12  2020  2020
# 370  2020-12-28  3.610189e+07           GASTOS VARIOS   28   12  2020  2020
# 372  2020-12-28  3.357936e+07           GASTOS VARIOS   28   12  2020  2020
# 374  2020-12-28  1.336286e+07           GASTOS VARIOS   28   12  2020  2020
# 586  2020-12-30  1.930300e+07           GASTOS VARIOS   30   12  2020  2020
# 801  2020-12-08  1.134577e+07  CONTRATISTAS Y FDO FED    8   12  2020  2020
# 851  2020-12-18  2.172712e+07  CONTRATISTAS Y FDO FED   18   12  2020  2020
# 856  2020-12-11  1.951267e+07  CONTRATISTAS Y FDO FED   11   12  2020  2020
# 858  2020-12-08  1.267303e+08  CONTRATISTAS Y FDO FED    8   12  2020  2020
# 968  2020-12-28  9.612407e+06  CONTRATISTAS Y FDO FED   28   12  2020  2020
#
#      BENEFICIARIO_SALE  IMPORTE_GASTOS_PROMEDIO  HAS_LINKEDIN_SITE  \
# 283                  2            881659.731797               True
# 353                  2            881659.731797               True
# 354                  2            881659.731797               True
# 357                  1            881659.731797              False
# 367                 16            881659.731797               True
# 368                 16            881659.731797               True
# 369                 16            881659.731797               True
# 370                 16            881659.731797               True
# 372                 16            881659.731797               True
# 374                 16            881659.731797               True
# 586                  2            881659.731797               True
# 801                  1            474566.765787               True
# 851                 78            474566.765787               True
# 856                  1            474566.765787               True
# 858                  5            474566.765787               True
# 968                  3            474566.765787               True
#
#      CLUSTER_NAME  PROB_TOTAL
# 283             1    0.959794
# 353             4    0.961068
# 354             4    0.961191
# 357             4    1.000000
# 367             1    1.000000
# 368             1    1.000000
# 369             1    0.999951
# 370             1    1.000000
# 372             1    1.000000
# 374             1    0.996115
# 586             4    0.999953
# 801             4    0.987439
# 851             4    0.999995
# 856             1    0.999961
# 858             4    1.000000
# 968             0    0.969710

# %%
models_sheet={}
for sheet in list(compras_df['SHEET'].unique()):
    sheet_compras = compras_df[compras_df['SHEET'] == sheet]
    params = norm.fit(sheet_compras['IMPORTE'])
    models_sheet[sheet] = norm(params[0], params[1])

# %%
sheet_prob = []
for i, row in compras_df.iterrows():
    sheet_prob.append(models_sheet[row['SHEET']].cdf(row['IMPORTE']))
compras_df['PROB_SHEET'] = sheet_prob

# %%
compras_df['PROB_SHEET'].hist()
# Out:
# <AxesSubplot: >

# %%
compras_df[compras_df['PROB_SHEET']>0.95]
# Out:
#       NUM BEN                                       BENEFICIARIO  \
# 283    116684                INDUSTRIAS SOLA BASIC, S.A. DE C.V.
# 353    126224                          BANCO MULTIVA, SA. G.F.M.
# 354    126224                          BANCO MULTIVA, SA. G.F.M.
# 357    126671       BANCO BANCREA,S.A. ,FIDEICOMISO NUMERO BP417
# 367    206894                MUNICIPIO DE LA CIUDAD DE MONTERREY
# 368    206894                MUNICIPIO DE LA CIUDAD DE MONTERREY
# 369    206894                MUNICIPIO DE LA CIUDAD DE MONTERREY
